# %% [markdown]
# ### Cirrhosis Dataset

# %%
# For EDA and Preprocessing
import pandas as pd
from datetime import datetime
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Load Datasets

# %%
cirrhosis_data = pd.read_csv('./cirrhosis.csv')

# %%
cirrhosis_data.head()
# Out:
#    ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly Spiders  \
# 0   1     400      D  D-penicillamine  21464   F       Y            Y       Y
# 1   2    4500      C  D-penicillamine  20617   F       N            Y       Y
# 2   3    1012      D  D-penicillamine  25594   M       N            N       N
# 3   4    1925      D  D-penicillamine  19994   F       N            Y       Y
# 4   5    1504     CL          Placebo  13918   F       N            Y       Y
#
#   Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# 0     Y       14.5        261.0     2.60   156.0    1718.0  137.95
# 1     N        1.1        302.0     4.14    54.0    7394.8  113.52
# 2     S        1.4        176.0     3.48   210.0     516.0   96.10
# 3     S        1.8        244.0     2.54    64.0    6121.8   60.63
# 4     N        3.4        279.0     3.53   143.0     671.0  113.15
#
#    Tryglicerides  Platelets  Prothrombin  Stage
# 0          172.0      190.0         12.2    4.0
# 1           88.0      221.0         10.6    3.0
# 2           55.0      151.0         12.0    4.0
# 3           92.0      183.0         10.3    4.0
# 4           72.0      136.0         10.9    3.0

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ## Dataset Overview

# %%
#check datasets shape
cirrhosis_data.shape
# Out:
# (418, 20)

# %%
# Check dataset columns
cirrhosis_data.columns
# Out:
# Index(['ID', 'N_Days', 'Status', 'Drug', 'Age', 'Sex', 'Ascites',
#        'Hepatomegaly', 'Spiders', 'Edema', 'Bilirubin', 'Cholesterol',
#        'Albumin', 'Copper', 'Alk_Phos', 'SGOT', 'Tryglicerides', 'Platelets',
#        'Prothrombin', 'Stage'],
#       dtype='object')

# %%
cirrhosis_data.describe()
# Out:
#                ID       N_Days           Age   Bilirubin  Cholesterol  \
# count  418.000000   418.000000    418.000000  418.000000   284.000000
# mean   209.500000  1917.782297  18533.351675    3.220813   369.510563
# std    120.810458  1104.672992   3815.845055    4.407506   231.944545
# min      1.000000    41.000000   9598.000000    0.300000   120.000000
# 25%    105.250000  1092.750000  15644.500000    0.800000   249.500000
# 50%    209.500000  1730.000000  18628.000000    1.400000   309.500000
# 75%    313.750000  2613.500000  21272.500000    3.400000   400.000000
# max    418.000000  4795.000000  28650.000000   28.000000  1775.000000
#
#           Albumin      Copper      Alk_Phos        SGOT  Tryglicerides  \
# count  418.000000  310.000000    312.000000  312.000000     282.000000
# mean     3.497440   97.648387   1982.655769  122.556346     124.702128
# std      0.424972   85.613920   2140.388824   56.699525      65.148639
# min      1.960000    4.000000    289.000000   26.350000      33.000000
# 25%      3.242500   41.250000    871.500000   80.600000      84.250000
# 50%      3.530000   73.000000   1259.000000  114.700000     108.000000
# 75%      3.770000  123.000000   1980.000000  151.900000     151.000000
# max      4.640000  588.000000  13862.400000  457.250000     598.000000
#
#         Platelets  Prothrombin       Stage
# count  407.000000   416.000000  412.000000
# mean   257.024570    10.731731    3.024272
# std     98.325585     1.022000    0.882042
# min     62.000000     9.000000    1.000000
# 25%    188.500000    10.000000    2.000000
# 50%    251.000000    10.600000    3.000000
# 75%    318.000000    11.100000    4.000000
# max    721.000000    18.000000    4.000000

# %%
#Check dataset features types
cirrhosis_data.dtypes
# Out:
# ID                 int64
# N_Days             int64
# Status            object
# Drug              object
# Age                int64
# Sex               object
# Ascites           object
# Hepatomegaly      object
# Spiders           object
# Edema             object
# Bilirubin        float64
# Cholesterol      float64
# Albumin          float64
# Copper           float64
# Alk_Phos         float64
# SGOT             float64
# Tryglicerides    float64
# Platelets        float64
# Prothrombin      float64
# Stage            float64
# dtype: object

# %% [markdown]
# ## Handling Duplicates

# %%
# Drop duplicate data
cirrhosis_data = cirrhosis_data.drop_duplicates()
cirrhosis_data
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 0      1     400      D  D-penicillamine  21464   F       Y            Y
# 1      2    4500      C  D-penicillamine  20617   F       N            Y
# 2      3    1012      D  D-penicillamine  25594   M       N            N
# 3      4    1925      D  D-penicillamine  19994   F       N            Y
# 4      5    1504     CL          Placebo  13918   F       N            Y
# ..   ...     ...    ...              ...    ...  ..     ...          ...
# 413  414     681      D              NaN  24472   F     NaN          NaN
# 414  415    1103      C              NaN  14245   F     NaN          NaN
# 415  416    1055      C              NaN  20819   F     NaN          NaN
# 416  417     691      C              NaN  21185   F     NaN          NaN
# 417  418     976      C              NaN  19358   F     NaN          NaN
#
#     Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# 0         Y     Y       14.5        261.0     2.60   156.0    1718.0  137.95
# 1         Y     N        1.1        302.0     4.14    54.0    7394.8  113.52
# 2         N     S        1.4        176.0     3.48   210.0     516.0   96.10
# 3         Y     S        1.8        244.0     2.54    64.0    6121.8   60.63
# 4         Y     N        3.4        279.0     3.53   143.0     671.0  113.15
# ..      ...   ...        ...          ...      ...     ...       ...     ...
# 413     NaN     N        1.2          NaN     2.96     NaN       NaN     NaN
# 414     NaN     N        0.9          NaN     3.83     NaN       NaN     NaN
# 415     NaN     N        1.6          NaN     3.42     NaN       NaN     NaN
# 416     NaN     N        0.8          NaN     3.75     NaN       NaN     NaN
# 417     NaN     N        0.7          NaN     3.29     NaN       NaN     NaN
#
#      Tryglicerides  Platelets  Prothrombin  Stage
# 0            172.0      190.0         12.2    4.0
# 1             88.0      221.0         10.6    3.0
# 2             55.0      151.0         12.0    4.0
# 3             92.0      183.0         10.3    4.0
# 4             72.0      136.0         10.9    3.0
# ..             ...        ...          ...    ...
# 413            NaN      174.0         10.9    3.0
# 414            NaN      180.0         11.2    4.0
# 415            NaN      143.0          9.9    3.0
# 416            NaN      269.0         10.4    3.0
# 417            NaN      350.0         10.6    4.0
#
# [418 rows x 20 columns]

# %% [markdown]
# ### Transforming Age

# %%
# Transfrom Age from days to years
cirrhosis_data['Age'] = (cirrhosis_data['Age']/365).round()
cirrhosis_data['Age']
# Out:
# 0      59.0
# 1      56.0
# 2      70.0
# 3      55.0
# 4      38.0
#        ...
# 413    67.0
# 414    39.0
# 415    57.0
# 416    58.0
# 417    53.0
# Name: Age, Length: 418, dtype: float64

# %% [markdown]
# ## Numerical and Categorical Features

# %%
# Checking numerical and categorical features
numerical_cols = []
categorical_cols = []

for column in cirrhosis_data.columns:
    if pd.api.types.is_numeric_dtype(cirrhosis_data[column]):
        numerical_cols.append(column)
    else:
        categorical_cols.append(column)

print(f'Numerical Features: {len(numerical_cols)} ,{numerical_cols}')     
print(f'Categorical Features: {len(categorical_cols)} ,{categorical_cols}')
# Out:
# Numerical Features: 13 ,['ID', 'N_Days', 'Age', 'Bilirubin', 'Cholesterol', 'Albumin', 'Copper', 'Alk_Phos', 'SGOT', 'Tryglicerides', 'Platelets', 'Prothrombin', 'Stage']
# Categorical Features: 7 ,['Status', 'Drug', 'Sex', 'Ascites', 'Hepatomegaly', 'Spiders', 'Edema']

# %%
cirrhosis_data.isna().sum()
# Out:
# ID                 0
# N_Days             0
# Status             0
# Drug             106
# Age                0
# Sex                0
# Ascites          106
# Hepatomegaly     106
# Spiders          106
# Edema              0
# Bilirubin          0
# Cholesterol      134
# Albumin            0
# Copper           108
# Alk_Phos         106
# SGOT             106
# Tryglicerides    136
# Platelets         11
# Prothrombin        2
# Stage              6
# dtype: int64

# %% [markdown]
# ## Univariate Analysis

# %%
# Check the skrew of data
# Create subplots for kde plots
fig, axes = plt.subplots(nrows=5, ncols=3, figsize=(10, 10))
fig.tight_layout()

# Iterate through the list and create kde plots
for i, k in enumerate(numerical_cols):
    row, col = divmod(i, 3)
    sns.kdeplot(data = cirrhosis_data,x=k, fill=True, ax=axes[row, col])
    axes[row, col].set_title(k)
plt.subplots_adjust(hspace=0.6)
plt.show()

# %%
# Countplot for categorical features
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(8, 12))
fig.tight_layout()

# Iterate through the list of categorical features and create count plots
for i, feature in enumerate(categorical_cols):
    row, col = divmod(i, 2)
    ax = sns.countplot(data=cirrhosis_data, x=feature, ax=axes[row, col])
     # Add count annotations above each bar
    for p in ax.patches:
        ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='bottom')
    axes[row, col].set_title(f'Count Plot of {feature}')
plt.subplots_adjust(hspace=0.6)
plt.show()

# %% [markdown]
# ## Pair Plot

# %%
numerical_columns = ['Age', 'Bilirubin', 'Albumin', 'Copper', 'Tryglicerides', 'Platelets', 'Prothrombin']

sns.pairplot(cirrhosis_data[numerical_columns + ['Status']], hue='Status', diag_kind='kde')
plt.show()

# %% [markdown]
# Most of the numerical features such as Bilirubin, Prothrombin, Triglycerides, etc. follow the Gaussian distribution so their missing values can be imputed with their corresponding median values.

# %% [markdown]
# ## Data PreProcessing

# %% [markdown]
# # Imputation

# %%
cirrhosis_data.isna().sum()
# Out:
# ID                 0
# N_Days             0
# Status             0
# Drug             106
# Age                0
# Sex                0
# Ascites          106
# Hepatomegaly     106
# Spiders          106
# Edema              0
# Bilirubin          0
# Cholesterol      134
# Albumin            0
# Copper           108
# Alk_Phos         106
# SGOT             106
# Tryglicerides    136
# Platelets         11
# Prothrombin        2
# Stage              6
# dtype: int64

# %%
# Drop rows with missing values in columns with less null values
columns_to_dropna = ['Platelets', 'Prothrombin', 'Stage']
cirrhosis_data = cirrhosis_data.dropna(subset=columns_to_dropna)

# %%
# Impute missing values for numeric columns with mean
cirrhosis_data[numerical_cols] = cirrhosis_data[numerical_cols].apply(lambda x: x.fillna(x.median()))

# Impute missing values for categorical columns with mode
cirrhosis_data[categorical_cols] = cirrhosis_data[categorical_cols].apply(lambda x: x.fillna(x.mode()[0]))

# %%
#Drop unnecessary columns
cirrhosis_data.drop(columns=['ID'],inplace=True)

# %%
cirrhosis_data.dropna()
# Out:
#      N_Days Status             Drug   Age Sex Ascites Hepatomegaly Spiders  \
# 0       400      D  D-penicillamine  59.0   F       Y            Y       Y
# 1      4500      C  D-penicillamine  56.0   F       N            Y       Y
# 2      1012      D  D-penicillamine  70.0   M       N            N       N
# 3      1925      D  D-penicillamine  55.0   F       N            Y       Y
# 4      1504     CL          Placebo  38.0   F       N            Y       Y
# ..      ...    ...              ...   ...  ..     ...          ...     ...
# 413     681      D  D-penicillamine  67.0   F       N            Y       N
# 414    1103      C  D-penicillamine  39.0   F       N            Y       N
# 415    1055      C  D-penicillamine  57.0   F       N            Y       N
# 416     691      C  D-penicillamine  58.0   F       N            Y       N
# 417     976      C  D-penicillamine  53.0   F       N            Y       N
#
#     Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# 0       Y       14.5        261.0     2.60   156.0    1718.0  137.95
# 1       N        1.1        302.0     4.14    54.0    7394.8  113.52
# 2       S        1.4        176.0     3.48   210.0     516.0   96.10
# 3       S        1.8        244.0     2.54    64.0    6121.8   60.63
# 4       N        3.4        279.0     3.53   143.0     671.0  113.15
# ..    ...        ...          ...      ...     ...       ...     ...
# 413     N        1.2        310.0     2.96    73.0    1264.0  116.25
# 414     N        0.9        310.0     3.83    73.0    1264.0  116.25
# 415     N        1.6        310.0     3.42    73.0    1264.0  116.25
# 416     N        0.8        310.0     3.75    73.0    1264.0  116.25
# 417     N        0.7        310.0     3.29    73.0    1264.0  116.25
#
#      Tryglicerides  Platelets  Prothrombin  Stage
# 0            172.0      190.0         12.2    4.0
# 1             88.0      221.0         10.6    3.0
# 2             55.0      151.0         12.0    4.0
# 3             92.0      183.0         10.3    4.0
# 4             72.0      136.0         10.9    3.0
# ..             ...        ...          ...    ...
# 413          108.0      174.0         10.9    3.0
# 414          108.0      180.0         11.2    4.0
# 415          108.0      143.0          9.9    3.0
# 416          108.0      269.0         10.4    3.0
# 417          108.0      350.0         10.6    4.0
#
# [399 rows x 19 columns]

# %%
cirrhosis_data.isna().sum()
# Out:
# N_Days           0
# Status           0
# Drug             0
# Age              0
# Sex              0
# Ascites          0
# Hepatomegaly     0
# Spiders          0
# Edema            0
# Bilirubin        0
# Cholesterol      0
# Albumin          0
# Copper           0
# Alk_Phos         0
# SGOT             0
# Tryglicerides    0
# Platelets        0
# Prothrombin      0
# Stage            0
# dtype: int64

# %%
cirrhosis_data['Status'].unique()
# Out:
# array(['D', 'C', 'CL'], dtype=object)

# %% [markdown]
# # Encoding

# %% [markdown]
# Use of MinMaxScaler and LabelEncoder to scale specified columns and encode categorical columns

# %%
from sklearn.preprocessing import MinMaxScaler
columns_to_scale = ['Bilirubin', 'Cholesterol', 'Albumin', 'Copper', 'Alk_Phos', 'SGOT', 'Tryglicerides', 'Platelets', 'Prothrombin']
scaler = MinMaxScaler()
cirrhosis_data[columns_to_scale] = scaler.fit_transform(cirrhosis_data[columns_to_scale])

# %%
cols_for_label_encoder = ['Status', 'Drug', 'Sex', 'Ascites', 'Hepatomegaly', 'Spiders', 'Edema', 'Stage']

from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
for col in cols_for_label_encoder:
    cirrhosis_data[col] = label_encoder.fit_transform(cirrhosis_data[col])

# %%
cirrhosis_data.head()
# Out:
#    N_Days  Status  Drug   Age  Sex  Ascites  Hepatomegaly  Spiders  Edema  \
# 0     400       2     0  59.0    0        1             1        1      2
# 1    4500       0     0  56.0    0        0             1        1      0
# 2    1012       2     0  70.0    1        0             0        0      1
# 3    1925       2     0  55.0    0        0             1        1      1
# 4    1504       1     1  38.0    0        0             1        1      0
#
#    Bilirubin  Cholesterol   Albumin    Copper  Alk_Phos      SGOT  \
# 0   0.512635     0.085196  0.238806  0.260274  0.105279  0.258993
# 1   0.028881     0.109970  0.813433  0.085616  0.523509  0.202298
# 2   0.039711     0.033837  0.567164  0.352740  0.016724  0.161871
# 3   0.054152     0.074924  0.216418  0.102740  0.429723  0.079554
# 4   0.111913     0.096073  0.585821  0.238014  0.028143  0.201439
#
#    Tryglicerides  Platelets  Prothrombin  Stage
# 0       0.246018   0.255489     0.395062      3
# 1       0.097345   0.317365     0.197531      2
# 2       0.038938   0.177645     0.370370      3
# 3       0.104425   0.241517     0.160494      3
# 4       0.069027   0.147705     0.234568      2

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# Correlation Matrix

# %%
# Correlation Matrix 
plt.figure(figsize=(10,10))
sns.heatmap(cirrhosis_data.corr(), fmt=".2f", annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# Predictive Power Score

# %%
# Predictive Power Score
import ppscore as pps
#Create another dataframe to used with pps (just in case that adjusting the features for this)
df_pps=cirrhosis_data.copy()
matrix_df_pps = pps.matrix(df_pps)[['x', 'y', 'ppscore']].pivot(columns='x', index='y', values='ppscore')
plt.figure(figsize=(15,15))
sns.heatmap(matrix_df_pps, vmin=0, vmax=1, fmt=".2f", cmap="Blues", linewidths=0.5, annot=True)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
#Use of SelectKBest with ANOVA F-statistic to select the top k features.
from sklearn.feature_selection import SelectKBest, f_classif

selector = SelectKBest(score_func=f_classif, k='all')
X_new = selector.fit_transform(X, y)

# Display feature scores
feature_scores = pd.DataFrame({'Feature': X.columns, 'Score': selector.scores_})
feature_scores.sort_values(by='Score', ascending=False, inplace=True)
print("Feature Scores:\n", feature_scores)

# Select the top k features (adjust k as needed)
k = 10
selected_features = feature_scores.head(k)['Feature'].tolist()
X_selected = X[selected_features]

# Display selected features
print(f"Selected Features (Top {k}):\n", selected_features)
# Out:
# Feature Scores:
#            Feature      Score
# 8       Bilirubin  45.149183
# 0          N_Days  40.293280
# 16    Prothrombin  37.465878
# 11         Copper  28.978657
# 7           Edema  22.628495
# 17          Stage  22.606804
# 4         Ascites  20.193072
# 2             Age  18.802430
# 10        Albumin  16.789156
# 13           SGOT  14.899358
# 5    Hepatomegaly  11.266406
# 12       Alk_Phos  10.833484
# 6         Spiders  10.744377
# 14  Tryglicerides   8.275825
# 9     Cholesterol   6.643119
# 15      Platelets   6.518407
# 3             Sex   3.726699
# 1            Drug   0.088217
# Selected Features (Top 10):
#  ['Bilirubin', 'N_Days', 'Prothrombin', 'Copper', 'Edema', 'Stage', 'Ascites', 'Age', 'Albumin', 'SGOT']

# %% [markdown]
# ## PreProcessing

# %%
X = cirrhosis_data.drop(columns=['Status'])
X
# Out:
#      N_Days  Drug   Age  Sex  Ascites  Hepatomegaly  Spiders  Edema  \
# 0       400     0  59.0    0        1             1        1      2
# 1      4500     0  56.0    0        0             1        1      0
# 2      1012     0  70.0    1        0             0        0      1
# 3      1925     0  55.0    0        0             1        1      1
# 4      1504     1  38.0    0        0             1        1      0
# ..      ...   ...   ...  ...      ...           ...      ...    ...
# 413     681     0  67.0    0        0             1        0      0
# 414    1103     0  39.0    0        0             1        0      0
# 415    1055     0  57.0    0        0             1        0      0
# 416     691     0  58.0    0        0             1        0      0
# 417     976     0  53.0    0        0             1        0      0
#
#      Bilirubin  Cholesterol   Albumin    Copper  Alk_Phos      SGOT  \
# 0     0.512635     0.085196  0.238806  0.260274  0.105279  0.258993
# 1     0.028881     0.109970  0.813433  0.085616  0.523509  0.202298
# 2     0.039711     0.033837  0.567164  0.352740  0.016724  0.161871
# 3     0.054152     0.074924  0.216418  0.102740  0.429723  0.079554
# 4     0.111913     0.096073  0.585821  0.238014  0.028143  0.201439
# ..         ...          ...       ...       ...       ...       ...
# 413   0.032491     0.114804  0.373134  0.118151  0.071832  0.208633
# 414   0.021661     0.114804  0.697761  0.118151  0.071832  0.208633
# 415   0.046931     0.114804  0.544776  0.118151  0.071832  0.208633
# 416   0.018051     0.114804  0.667910  0.118151  0.071832  0.208633
# 417   0.014440     0.114804  0.496269  0.118151  0.071832  0.208633
#
#      Tryglicerides  Platelets  Prothrombin  Stage
# 0         0.246018   0.255489     0.395062      3
# 1         0.097345   0.317365     0.197531      2
# 2         0.038938   0.177645     0.370370      3
# 3         0.104425   0.241517     0.160494      3
# 4         0.069027   0.147705     0.234568      2
# ..             ...        ...          ...    ...
# 413       0.132743   0.223553     0.234568      2
# 414       0.132743   0.235529     0.271605      3
# 415       0.132743   0.161677     0.111111      2
# 416       0.132743   0.413174     0.172840      2
# 417       0.132743   0.574850     0.197531      3
#
# [399 rows x 18 columns]

# %%
y = cirrhosis_data['Status']
y
# Out:
# 0      2
# 1      0
# 2      2
# 3      2
# 4      1
#       ..
# 413    2
# 414    0
# 415    0
# 416    0
# 417    0
# Name: Status, Length: 399, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X[selected_features], y, test_size=0.25,random_state=1)

# %%
X_train[selected_features].isna().sum()
# Out:
# Bilirubin      0
# N_Days         0
# Prothrombin    0
# Copper         0
# Edema          0
# Stage          0
# Ascites        0
# Age            0
# Albumin        0
# SGOT           0
# dtype: int64

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import StandardScaler

# feature scaling helps improve reach convergence faster
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test  = scaler.transform(X_test)

# %% [markdown]
# # Modeling

# %%
from sklearn.metrics import accuracy_score, classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

models = {
    'Logistic Regression': LogisticRegression(),
    'Random Forest': RandomForestClassifier()
}

for model_name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    # Calculate accuracy
    accuracy = accuracy_score(y_test, y_pred)
    classification_report_str = classification_report(y_test, y_pred)

    # Print results
    print(f'Accuracy for {model_name}: {accuracy:.2f}')
    print(f'Classification Report for {model_name}:\n{classification_report_str}\n')
# Out:
# Accuracy for Logistic Regression: 0.76
# Classification Report for Logistic Regression:
#               precision    recall  f1-score   support
#
#            0       0.86      0.91      0.88        66
#            1       0.00      0.00      0.00        11
#            2       0.53      0.70      0.60        23
#
#     accuracy                           0.76       100
#    macro avg       0.46      0.53      0.50       100
# weighted avg       0.69      0.76      0.72       100
#
#
# Accuracy for Random Forest: 0.75
# Classification Report for Random Forest:
#               precision    recall  f1-score   support
#
#            0       0.85      0.91      0.88        66
#            1       0.00      0.00      0.00        11
#            2       0.52      0.65      0.58        23
#
#     accuracy                           0.75       100
#    macro avg       0.45      0.52      0.48       100
# weighted avg       0.68      0.75      0.71       100
